# %%
import pandas as pd
test = pd.read_csv("Data/test.csv")
train = pd.read_csv("Data/train.csv")
sampleSubmission = pd.read_csv("Data/sampleSubmission.csv")
train = pd.concat([train, test]) # put the datasets together

# %%
#train.describe()
#Let's plot the registered and casual according to atemp
import matplotlib as plt
# %matplotlib inline

train.plot(x='atemp',y='count',kind='scatter')

# %%
#Let's figure this out by casual vs registered. These seem to be two very different populations
import matplotlib.pyplot as plt
plt.figure()
fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(15,8))
train.plot(x='atemp',y='casual',kind='scatter', ax=axes[0,0])
train.plot(x='atemp',y='registered',kind='scatter', ax = axes[0,1])
train.plot(x='temp',y='casual',kind='scatter', ax=axes[1,0])
train.plot(x='temp',y='registered',kind='scatter', ax = axes[1,1])

# %%
fig,axes = plt.subplots(nrows=4,ncols=2,figsize=(15,8))
#let's look at it for each season

train[train['season']==1].plot(x='temp',y='casual',kind='scatter', ax=axes[0,0], label ='Spring')
train[train['season']==1].plot(x='temp',y='registered',kind='scatter', ax = axes[0,1], label ='Spring')
train[train['season']==2].plot(x='temp',y='casual',kind='scatter', ax=axes[1,0], label ='Summer')
train[train['season']==2].plot(x='temp',y='registered',kind='scatter', ax = axes[1,1], label ='Summer')
train[train['season']==3].plot(x='temp',y='casual',kind='scatter', ax=axes[2,0], label = 'Fall')
train[train['season']==3].plot(x='temp',y='registered',kind='scatter', ax = axes[2,1], label = 'Fall')
train[train['season']==4].plot(x='temp',y='casual',kind='scatter', ax=axes[3,0], label = 'Winter')
train[train['season']==4].plot(x='temp',y='registered',kind='scatter', ax = axes[3,1], label = 'Winter')

# %%
#Create function to calculate null vars
def print_null_freq(df):
     """
     for a given DataFrame, calculates how many values for 
     each variable is null and prints the resulting table to stdout
     """
     # use melt to convert from wide to long format e.g. table to key, value pair
     df_lng = pd.melt(df)
     null_variables = df_lng.value.isnull()
     return pd.crosstab(df_lng.variable, null_variables)
print_null_freq(train)
# Out:
# value       False  True
# variable
# atemp       17379      0
# casual      10886   6493
# count       10886   6493
# datetime    17379      0
# holiday     17379      0
# humidity    17379      0
# registered  10886   6493
# season      17379      0
# temp        17379      0
# weather     17379      0
# windspeed   17379      0
# workingday  17379      0

# %%
train['time'] = train['datetime'].str.split(' ').str[1].str[0:2].convert_objects(convert_numeric=True)
train['date'] = train['datetime'].str.split(' ').str[0]
train['date'] = pd.to_datetime(train['date'])
workdays = train[train['workingday']==1]['date']
nonworkdays = train[train['workingday']==0]['date']
holidays = train[train['holiday']==1]['date']


import numpy as np
import datetime
import pandas as pd
one_day = datetime.timedelta(days = 1)
nonworkdays = nonworkdays - one_day
intersect = np.intersect1d(nonworkdays,workdays)
a = pd.to_datetime(np.unique(intersect))

intersect = np.intersect1d(nonworkdays,workdays)
b_nwday = pd.to_datetime(np.unique(intersect))

train['b_nwday'] = train.apply(lambda row: row['date'] in b_nwday, axis=1)


#let's look at it for each season
grouped = train.groupby(by=['time','b_nwday'])
a = grouped.median()[['casual','registered']].reset_index()

fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(15,8))
a[a['b_nwday']==1].plot(x='time', y='casual', kind='scatter', ax=axes[0,0],label='casual, wday before nonworkday')
a[a['b_nwday']==1].plot(x='time', y='registered', kind='scatter', ax=axes[0,1],label='registered, wday before nonworkday')
a[a['b_nwday']==0].plot(x='time', y='casual', kind='scatter', ax=axes[1,0],label='casual, not before nonworkday')
a[a['b_nwday']==0].plot(x='time', y='registered', kind='scatter', ax=axes[1,1],label='registered, not nonworkday')

# %%
#Do people play hookie before holidays

train['time'] = train['datetime'].str.split(' ').str[1].str[0:2].convert_objects(convert_numeric=True)
train['date'] = train['datetime'].str.split(' ').str[0]
train['date'] = pd.to_datetime(train['date'])
workdays = train[train['workingday']==1]['date']
nonworkdays = train[train['workingday']==0]['date']
holidays = train[train['holiday']==1]['date']


import numpy as np
import datetime
import pandas as pd
one_day = datetime.timedelta(days = 1)
holidays_1 = holidays - one_day
holidays_2 = holidays - one_day - one_day
holidays_3 = holidays - one_day - one_day - one_day
intersect1 = np.intersect1d(holidays_1,workdays)
intersect2 = np.intersect1d(holidays_2,workdays)
intersect3 = np.intersect1d(holidays_3,workdays)
intersect = np.append(intersect1,intersect2)
intersect = np.append(intersect,intersect3)
holidays = pd.to_datetime(np.unique(intersect))

intersect = np.intersect1d(holidays,workdays)
b_holiday = pd.to_datetime(np.unique(intersect))

train['b_holiday'] = train.apply(lambda row: row['date'] in b_holiday, axis=1)

grouped = train.groupby(by=['time','b_holiday'])
a = grouped.median()[['casual','registered']].reset_index()

fig,axes = plt.subplots(nrows=4,ncols=2,figsize=(15,8))
train[train['b_holiday']==1].plot(x='time', y='casual', kind='scatter', ax=axes[0,0])#,label='casual, wday before holiday')
train[train['b_holiday']==1].plot(x='time', y='registered', kind='scatter', ax=axes[0,1])#,label='registered, wday before  holiday')
train[train['b_holiday']==0].plot(x='time', y='casual', kind='scatter', ax=axes[1,0])#,label='casual, not before  holiday')
train[train['b_holiday']==0].plot(x='time', y='registered', kind='scatter', ax=axes[1,1])#,label='registered, not  holiday')
a[a['b_holiday']==1].plot(x='time', y='casual', kind='line', ax=axes[2,0])#,label='casual, wday before holiday')
a[a['b_holiday']==1].plot(x='time', y='registered', kind='line', ax=axes[2,1])#,label='registered, wday before  holiday')
a[a['b_holiday']==0].plot(x='time', y='casual', kind='line', ax=axes[3,0])#,label='casual, not before  holiday')
a[a['b_holiday']==0].plot(x='time', y='registered', kind='line', ax=axes[3,1])#,label='registered, not  holiday')

# %%
#Does working day really matter? Not really, everyone just rides not during lunch.
fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(15,8))
train[train['workingday']==0].plot(x='time',y='casual', ax=axes[0,0])
train[train['workingday']==0].plot(x='time',y='registered', ax=axes[0,1])
train[train['workingday']==1].plot(x='time',y='casual', ax=axes[1,0])
train[train['workingday']==1].plot(x='time',y='registered', ax=axes[1,1])

# %%
#Create peak hour feature
train['day'] = train['time'] > 7
train['m_peak'] = (train['time'] > 7) & (train['time'] < 10)
train['n_peak'] = (train['time'] > 15) & (train['time'] < 20)

# %%
#Let's see humidity's effect
import seaborn as sns
train['temp_r'] = train['temp'].round()
train['humi_r'] = train['humidity']/10
train['humi_r'] = train['humi_r'].round()
grouped = train.groupby(['temp_r', 'humi_r'])
a = grouped.median()[['casual','registered']]
areset = a.reset_index()
sns.heatmap(areset.pivot('temp_r','humi_r'))
sns.jointplot('humi_r','temp_r', data=areset)
#areset.columns = ['a', 'b', 'occurrence']
#hdfpivot=hdfreset.pivot('a', 'b')
    
#for grp, val in a.casual:
#    plt.plot(val,'o')
#for grp, val in data.df.groupby(level=data.header[0:-1])['concentration']:
#    plt.plot(val,'o')
#sns.heatmap(a)
#a.pivot['temp','humidity','casual']
#sns.heatmap(data=a,x='temp',y='humidity')
#a = train[['temp','humidity','registered','casual']]
#train.groupby('temp','humidity').median()
#train.pivot("temp", "humidity", "count")
#sns.heatmap(train, annot=True, fmt="d")

# %%
#fig,axes = plt.subplots(nrows=2,ncols=2,figsize=(15,8))
temp = train.groupby('temp_r').median()
temp = temp[['casual','registered']]
temp.plot()

train['atemp_r'] = train['atemp'].round()
atemp = train.groupby('atemp_r').median()
atemp = atemp[['casual','registered']]
atemp.plot()

humi = train.groupby('humidity').median()
humi = humi[['casual','registered']]
humi.plot()
#areset.plot(x='temp',y='casual', kind='scatter', ax=axes[0,0])
#areset.plot(x='humidity',y='casual', kind='scatter', ax=axes[0,1])
#areset.plot(x='temp',y='registered', kind='scatter', ax=axes[1,0])
#areset.plot(x='humidity',y='registered', kind='scatter', ax=axes[1,1])

# %% [markdown]
# ### Delay impact of weather

# %%
# Create feature for days since last rain

# first make feature for change of from weather = 3 to (2, 1)

one_hr = datetime.timedelta(hours = 1)
A = train[['datetime','weather']]
A['datetime'] = A['datetime'].apply(lambda x : datetime.datetime.strptime(x, "%Y-%m-%d %H:%M:%S"))

A['datetime'] = A['datetime'] - one_hr
A['weather_prev'] = A['weather']
A.drop('weather', 1, inplace=True)      
train['datetime'] = train['datetime'].apply(lambda x : datetime.datetime.strptime(x, "%Y-%m-%d %H:%M:%S"))

# %%
weather = train.merge(A, on='datetime')#[['datetime','weather','weather_prev']]
weather['stopped_rain'] = (weather['weather_prev'] == 3) & ((weather['weather'] == 2) | (weather['weather'] == 2))
weather
# Out:
#         atemp  casual  count            datetime  holiday  humidity  \
# 0      14.395       3     16 2011-01-01 00:00:00        0        81
# 1      13.635       8     40 2011-01-01 01:00:00        0        80
# 2      13.635       5     32 2011-01-01 02:00:00        0        80
# 3      14.395       3     13 2011-01-01 03:00:00        0        75
# 4      14.395       0      1 2011-01-01 04:00:00        0        75
# 5      12.880       0      1 2011-01-01 05:00:00        0        75
# 6      13.635       2      2 2011-01-01 06:00:00        0        80
# 7      12.880       1      3 2011-01-01 07:00:00        0        86
# 8      14.395       1      8 2011-01-01 08:00:00        0        75
# 9      17.425       8     14 2011-01-01 09:00:00        0        76
# 10     19.695      12     36 2011-01-01 10:00:00        0        76
# 11     16.665      26     56 2011-01-01 11:00:00        0        81
# 12     21.210      29     84 2011-01-01 12:00:00        0        77
# 13     22.725      47     94 2011-01-01 13:00:00        0        72
# 14     22.725      35    106 2011-01-01 14:00:00        0        72
# 15     21.970      40    110 2011-01-01 15:00:00        0        77
# 16     21.210      41     93 2011-01-01 16:00:00        0        82
# 17     21.970      15     67 2011-01-01 17:00:00        0        82
# 18     21.210       9     35 2011-01-01 18:00:00        0        88
# 19     21.210       6     37 2011-01-01 19:00:00        0        88
# 20     20.455      11     36 2011-01-01 20:00:00        0        87
# 21     20.455       3     34 2011-01-01 21:00:00        0        87
# 22     20.455      11     28 2011-01-01 22:00:00        0        94
# 23     22.725      15     39 2011-01-01 23:00:00        0        88
# 24     22.725       4     17 2011-01-02 00:00:00        0        88
# 25     21.970       1     17 2011-01-02 01:00:00        0        94
# 26     21.210       1      9 2011-01-02 02:00:00        0       100
# 27     22.725       2      6 2011-01-02 03:00:00        0        94
# 28     21.210       0      2 2011-01-02 06:00:00        0        77
# 29     20.455       0      1 2011-01-02 07:00:00        0        76
# ...       ...     ...    ...                 ...      ...       ...
# 17273  11.365     NaN    NaN 2012-12-30 17:00:00        0        41
# 17274  10.605     NaN    NaN 2012-12-30 18:00:00        0        44
# 17275  18.180     NaN    NaN 2012-12-30 19:00:00        0        61
# 17276   9.850     NaN    NaN 2012-12-30 20:00:00        0        47
# 17277  10.605     NaN    NaN 2012-12-30 21:00:00        0        51
# 17278   9.850     NaN    NaN 2012-12-30 22:00:00        0        55
# 17279   9.850     NaN    NaN 2012-12-30 23:00:00        0        51
# 17280   9.090     NaN    NaN 2012-12-31 00:00:00        0        55
# 17281   9.090     NaN    NaN 2012-12-31 01:00:00        0        55
# 17282   8.335     NaN    NaN 2012-12-31 02:00:00        0        59
# 17283   9.090     NaN    NaN 2012-12-31 03:00:00        0        59
# 17284   8.335     NaN    NaN 2012-12-31 04:00:00        0        69
# 17285   7.575     NaN    NaN 2012-12-31 05:00:00        0        64
# 17286   8.335     NaN    NaN 2012-12-31 06:00:00        0        64
# 17287   9.090     NaN    NaN 2012-12-31 07:00:00        0        64
# 17288   7.575     NaN    NaN 2012-12-31 08:00:00        0        69
# 17289  10.605     NaN    NaN 2012-12-31 09:00:00        0        64
# 17290  10.605     NaN    NaN 2012-12-31 10:00:00        0        69
# 17291  11.365     NaN    NaN 2012-12-31 11:00:00        0        60
# 17292  11.365     NaN    NaN 2012-12-31 12:00:00        0        56
# 17293  12.880     NaN    NaN 2012-12-31 13:00:00        0        44
# 17294  13.635     NaN    NaN 2012-12-31 14:00:00        0        45
# 17295  14.395     NaN    NaN 2012-12-31 15:00:00        0        45
# 17296  12.880     NaN    NaN 2012-12-31 16:00:00        0        48
# 17297  14.395     NaN    NaN 2012-12-31 17:00:00        0        48
# 17298  13.635     NaN    NaN 2012-12-31 18:00:00        0        48
# 17299  12.880     NaN    NaN 2012-12-31 19:00:00        0        60
# 17300  12.880     NaN    NaN 2012-12-31 20:00:00        0        60
# 17301  12.880     NaN    NaN 2012-12-31 21:00:00        0        60
# 17302  13.635     NaN    NaN 2012-12-31 22:00:00        0        56
#
#        registered  season   temp  weather      ...       b_nwday  b_holiday  \
# 0              13       1   9.84        1      ...         False      False
# 1              32       1   9.02        1      ...         False      False
# 2              27       1   9.02        1      ...         False      False
# 3              10       1   9.84        1      ...         False      False
# 4               1       1   9.84        1      ...         False      False
# 5               1       1   9.84        2      ...         False      False
# 6               0       1   9.02        1      ...         False      False
# 7               2       1   8.20        1      ...         False      False
# 8               7       1   9.84        1      ...         False      False
# 9               6       1  13.12        1      ...         False      False
# 10             24       1  15.58        1      ...         False      False
# 11             30       1  14.76        1      ...         False      False
# 12             55       1  17.22        1      ...         False      False
# 13             47       1  18.86        2      ...         False      False
# 14             71       1  18.86        2      ...         False      False
# 15             70       1  18.04        2      ...         False      False
# 16             52       1  17.22        2      ...         False      False
# 17             52       1  18.04        2      ...         False      False
# 18             26       1  17.22        3      ...         False      False
# 19             31       1  17.22        3      ...         False      False
# 20             25       1  16.40        2      ...         False      False
# 21             31       1  16.40        2      ...         False      False
# 22             17       1  16.40        2      ...         False      False
# 23             24       1  18.86        2      ...         False      False
# 24             13       1  18.86        2      ...         False      False
# 25             16       1  18.04        2      ...         False      False
# 26              8       1  17.22        2      ...         False      False
# 27              4       1  18.86        2      ...         False      False
# 28              2       1  17.22        3      ...         False      False
# 29              1       1  16.40        2      ...         False      False
# ...           ...     ...    ...      ...      ...           ...        ...
# 17273         NaN       1  10.66        1      ...         False      False
# 17274         NaN       1   9.84        2      ...         False      False
# 17275         NaN       1  13.94        1      ...         False      False
# 17276         NaN       1   9.02        1      ...         False      False
# 17277         NaN       1   8.20        1      ...         False      False
# 17278         NaN       1   8.20        1      ...         False      False
# 17279         NaN       1   8.20        1      ...         False      False
# 17280         NaN       1   7.38        1      ...         False      False
# 17281         NaN       1   7.38        1      ...         False      False
# 17282         NaN       1   6.56        1      ...         False      False
# 17283         NaN       1   6.56        1      ...         False      False
# 17284         NaN       1   5.74        1      ...         False      False
# 17285         NaN       1   6.56        1      ...         False      False
# 17286         NaN       1   6.56        1      ...         False      False
# 17287         NaN       1   6.56        1      ...         False      False
# 17288         NaN       1   5.74        1      ...         False      False
# 17289         NaN       1   7.38        2      ...         False      False
# 17290         NaN       1   8.20        2      ...         False      False
# 17291         NaN       1   9.02        2      ...         False      False
# 17292         NaN       1   9.84        2      ...         False      False
# 17293         NaN       1  10.66        2      ...         False      False
# 17294         NaN       1  11.48        2      ...         False      False
# 17295         NaN       1  11.48        2      ...         False      False
# 17296         NaN       1  10.66        2      ...         False      False
# 17297         NaN       1  10.66        2      ...         False      False
# 17298         NaN       1  10.66        2      ...         False      False
# 17299         NaN       1  10.66        2      ...         False      False
# 17300         NaN       1  10.66        2      ...         False      False
# 17301         NaN       1  10.66        1      ...         False      False
# 17302         NaN       1  10.66        1      ...         False      False
#
#          day m_peak n_peak temp_r humi_r atemp_r weather_prev  stopped_rain
# 0      False  False  False     10      8      14            1         False
# 1      False  False  False      9      8      14            1         False
# 2      False  False  False      9      8      14            1         False
# 3      False  False  False     10      8      14            1         False
# 4      False  False  False     10      8      14            2         False
# 5      False  False  False     10      8      13            1         False
# 6      False  False  False      9      8      14            1         False
# 7      False  False  False      8      9      13            1         False
# 8       True   True  False     10      8      14            1         False
# 9       True   True  False     13      8      17            1         False
# 10      True  False  False     16      8      20            1         False
# 11      True  False  False     15      8      17            1         False
# 12      True  False  False     17      8      21            2         False
# 13      True  False  False     19      7      23            2         False
# 14      True  False  False     19      7      23            2         False
# 15      True  False  False     18      8      22            2         False
# 16      True  False   True     17      8      21            2         False
# 17      True  False   True     18      8      22            3          True
# 18      True  False   True     17      9      21            3         False
# 19      True  False   True     17      9      21            2         False
# 20      True  False  False     16      9      20            2         False
# 21      True  False  False     16      9      20            2         False
# 22      True  False  False     16      9      20            2         False
# 23      True  False  False     19      9      23            2         False
# 24     False  False  False     19      9      23            2         False
# 25     False  False  False     18      9      22            2         False
# 26     False  False  False     17     10      21            2         False
# 27     False  False  False     19      9      23            2         False
# 28     False  False  False     17      8      21            2         False
# 29     False  False  False     16      8      20            3          True
# ...      ...    ...    ...    ...    ...     ...          ...           ...
# 17273   True  False   True     11      4      11            2         False
# 17274   True  False   True     10      4      11            1         False
# 17275   True  False   True     14      6      18            1         False
# 17276   True  False  False      9      5      10            1         False
# 17277   True  False  False      8      5      11            1         False
# 17278   True  False  False      8      6      10            1         False
# 17279   True  False  False      8      5      10            1         False
# 17280  False  False  False      7      6       9            1         False
# 17281  False  False  False      7      6       9            1         False
# 17282  False  False  False      7      6       8            1         False
# 17283  False  False  False      7      6       9            1         False
# 17284  False  False  False      6      7       8            1         False
# 17285  False  False  False      7      6       8            1         False
# 17286  False  False  False      7      6       8            1         False
# 17287  False  False  False      7      6       9            1         False
# 17288   True   True  False      6      7       8            2         False
# 17289   True   True  False      7      6      11            2         False
# 17290   True  False  False      8      7      11            2         False
# 17291   True  False  False      9      6      11            2         False
# 17292   True  False  False     10      6      11            2         False
# 17293   True  False  False     11      4      13            2         False
# 17294   True  False  False     11      4      14            2         False
# 17295   True  False  False     11      4      14            2         False
# 17296   True  False   True     11      5      13            2         False
# 17297   True  False   True     11      5      14            2         False
# 17298   True  False   True     11      5      14            2         False
# 17299   True  False   True     11      6      13            2         False
# 17300   True  False  False     11      6      13            1         False
# 17301   True  False  False     11      6      13            1         False
# 17302   True  False  False     11      6      14            1         False
#
# [17303 rows x 24 columns]

# %%
rains = weather[weather['stopped_rain'] == True]['datetime']

print list(rains)

zero_hrs = datetime.timedelta(hours=0)

def listalesce(list_obj):
    if not list_obj:
        return [zero_hrs]
    else:
        return list_obj


train['hrs_since_rain'] = train['datetime'].apply(lambda row :
                                                  min(listalesce(filter(lambda x:x > zero_hrs ,row - rains)))
                                                  )/one_hr
rain = train[['hrs_since_rain','time','registered','casual']]
#medians_rain = rain.groupby(['time','hrs_since_rain']).median().reset_index()
#medians_rain
#medians_rain.pivot('time','hrs_since_rain')['registered']
#medians_rain.plot(x='hrs_since_rain', y='registered', kind='scatter')
# Out:
# [Timestamp('2011-01-01 17:00:00'), Timestamp('2011-01-02 07:00:00'), Timestamp('2011-01-02 13:00:00'), Timestamp('2011-01-07 04:00:00'), Timestamp('2011-01-08 02:00:00'), Timestamp('2011-01-08 07:00:00'), Timestamp('2011-01-11 17:00:00'), Timestamp('2011-01-17 18:00:00'), Timestamp('2011-01-19 00:00:00'), Timestamp('2011-02-01 22:00:00'), Timestamp('2011-02-05 03:00:00'), Timestamp('2011-02-08 02:00:00'), Timestamp('2011-02-09 18:00:00'), Timestamp('2011-02-09 21:00:00'), Timestamp('2011-03-06 06:00:00'), Timestamp('2011-03-06 13:00:00'), Timestamp('2011-03-06 23:00:00'), Timestamp('2011-03-09 21:00:00'), Timestamp('2011-03-10 17:00:00'), Timestamp('2011-03-10 22:00:00'), Timestamp('2011-03-11 00:00:00'), Timestamp('2011-03-15 20:00:00'), Timestamp('2011-03-15 23:00:00'), Timestamp('2011-04-01 04:00:00'), Timestamp('2011-04-02 11:00:00'), Timestamp('2011-04-03 19:00:00'), Timestamp('2011-04-05 03:00:00'), Timestamp('2011-04-05 07:00:00'), Timestamp('2011-04-08 01:00:00'), Timestamp('2011-04-08 06:00:00'), Timestamp('2011-04-08 11:00:00'), Timestamp('2011-04-08 16:00:00'), Timestamp('2011-04-09 02:00:00'), Timestamp('2011-04-11 22:00:00'), Timestamp('2011-04-12 07:00:00'), Timestamp('2011-04-12 12:00:00'), Timestamp('2011-04-12 16:00:00'), Timestamp('2011-04-13 01:00:00'), Timestamp('2011-04-13 11:00:00'), Timestamp('2011-04-16 05:00:00'), Timestamp('2011-04-16 07:00:00'), Timestamp('2011-04-16 12:00:00'), Timestamp('2011-04-16 19:00:00'), Timestamp('2011-04-16 21:00:00'), Timestamp('2011-04-19 08:00:00'), Timestamp('2011-05-03 23:00:00'), Timestamp('2011-05-13 03:00:00'), Timestamp('2011-05-13 05:00:00'), Timestamp('2011-05-13 16:00:00'), Timestamp('2011-05-13 22:00:00'), Timestamp('2011-05-14 06:00:00'), Timestamp('2011-05-14 11:00:00'), Timestamp('2011-05-14 18:00:00'), Timestamp('2011-05-15 04:00:00'), Timestamp('2011-05-17 00:00:00'), Timestamp('2011-05-17 09:00:00'), Timestamp('2011-05-17 11:00:00'), Timestamp('2011-05-18 01:00:00'), Timestamp('2011-05-19 10:00:00'), Timestamp('2011-05-19 12:00:00'), Timestamp('2011-06-09 20:00:00'), Timestamp('2011-06-09 23:00:00'), Timestamp('2011-06-16 15:00:00'), Timestamp('2011-06-19 07:00:00'), Timestamp('2011-06-19 13:00:00'), Timestamp('2011-07-03 19:00:00'), Timestamp('2011-07-06 08:00:00'), Timestamp('2011-07-08 15:00:00'), Timestamp('2011-08-03 05:00:00'), Timestamp('2011-08-03 09:00:00'), Timestamp('2011-08-03 11:00:00'), Timestamp('2011-08-03 15:00:00'), Timestamp('2011-08-03 17:00:00'), Timestamp('2011-08-03 21:00:00'), Timestamp('2011-08-04 02:00:00'), Timestamp('2011-08-06 15:00:00'), Timestamp('2011-08-06 18:00:00'), Timestamp('2011-08-06 22:00:00'), Timestamp('2011-08-13 23:00:00'), Timestamp('2011-08-14 03:00:00'), Timestamp('2011-08-14 08:00:00'), Timestamp('2011-08-18 23:00:00'), Timestamp('2011-09-01 13:00:00'), Timestamp('2011-09-03 09:00:00'), Timestamp('2011-09-05 08:00:00'), Timestamp('2011-09-05 22:00:00'), Timestamp('2011-09-06 04:00:00'), Timestamp('2011-09-06 07:00:00'), Timestamp('2011-09-06 09:00:00'), Timestamp('2011-09-06 19:00:00'), Timestamp('2011-09-06 22:00:00'), Timestamp('2011-09-07 00:00:00'), Timestamp('2011-09-07 02:00:00'), Timestamp('2011-09-07 05:00:00'), Timestamp('2011-09-07 19:00:00'), Timestamp('2011-09-08 04:00:00'), Timestamp('2011-09-08 14:00:00'), Timestamp('2011-09-08 20:00:00'), Timestamp('2011-09-09 03:00:00'), Timestamp('2011-09-09 06:00:00'), Timestamp('2011-09-15 16:00:00'), Timestamp('2011-10-01 08:00:00'), Timestamp('2011-10-01 16:00:00'), Timestamp('2011-10-01 19:00:00'), Timestamp('2011-10-01 22:00:00'), Timestamp('2011-10-02 12:00:00'), Timestamp('2011-10-03 12:00:00'), Timestamp('2011-10-11 13:00:00'), Timestamp('2011-10-12 00:00:00'), Timestamp('2011-10-12 02:00:00'), Timestamp('2011-10-12 10:00:00'), Timestamp('2011-10-12 16:00:00'), Timestamp('2011-10-13 05:00:00'), Timestamp('2011-10-14 05:00:00'), Timestamp('2011-10-14 09:00:00'), Timestamp('2011-10-19 13:00:00'), Timestamp('2011-10-19 19:00:00'), Timestamp('2011-11-10 ...

# %%
rain[(rain['time'] > 7) & (rain['time'] < 20) & (rain['hrs_since_rain'] < 25)].plot(x='hrs_since_rain',y='casual', kind='scatter', )
rain[(rain['time'] > 7) & (rain['time'] < 20) & (rain['hrs_since_rain'] < 168)].groupby(by='hrs_since_rain').median().plot()

# %% [markdown]
# # Build model for Registered

# %%
print("\n Correlations \n")
train[['season','holiday','workingday','weather','temp','atemp','humidity','windspeed','time',
      'day','m_peak','n_peak','temp_r','humi_r','atemp_r','hrs_since_rain','registered', 'casual'
      ]].corr()[['registered','casual']]
# Out:
#  Correlations
#                 registered    casual
# season            0.164011  0.096758
# holiday          -0.020956  0.043799
# workingday        0.119460 -0.319111
# weather          -0.109340 -0.135918
# temp              0.318571  0.467097
# atemp             0.314635  0.462067
# humidity         -0.265458 -0.348187
# windspeed         0.091052  0.092276
# time              0.380540  0.302045
# day               0.489989  0.431762
# m_peak            0.220917 -0.059080
# n_peak            0.481276  0.262469
# temp_r            0.318415  0.466559
# humi_r           -0.264401 -0.344545
# atemp_r           0.313873  0.461425
# hrs_since_rain    0.057601  0.093560
# registered        1.000000  0.497250
# casual            0.497250  1.000000

# %%
from sklearn.linear_model import LinearRegression
import scipy, scipy.stats

Y = train[train['count'].notnull()].registered
X = train[train['count'].notnull()][['season','holiday','workingday','weather','temp','atemp','humidity','windspeed','time',
      'day','m_peak','n_peak','temp_r','humi_r','atemp_r','hrs_since_rain'
      ]].values

clf = LinearRegression(fit_intercept=False)
clf.fit(X,Y)

test['predict_registered'] = clf.predict(train[train['count'].isnull()][[
        'season','holiday','workingday','weather','temp','atemp','humidity','windspeed','time',
      'day','m_peak','n_peak','temp_r','humi_r','atemp_r','hrs_since_rain'
      ]].values)

# %%
Y = train[train['count'].notnull()].casual
X = train[train['count'].notnull()][['season','holiday','workingday','weather','temp','atemp','humidity','windspeed','time',
      'day','m_peak','n_peak','temp_r','humi_r','atemp_r','hrs_since_rain'
      ]].values

clf = LinearRegression(fit_intercept=False)
clf.fit(X,Y)

test['predict_casual'] = clf.predict(train[train['count'].isnull()][[
        'season','holiday','workingday','weather','temp','atemp','humidity','windspeed','time',
      'day','m_peak','n_peak','temp_r','humi_r','atemp_r','hrs_since_rain'
      ]].values)

# %%
test['count'] = test['predict_casual'] + test['predict_registered']

# %%
test['count'][test['count'] < 0] = 0 # destroy negative nums
# Out:
# -c:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test[['datetime','count']].to_csv('lin_reg.csv', index=False)

# %%
test[['time','count']].plot(x = 'time' ,y = 'count')
train[['time','count']][train['count'].notnull()].plot(x = 'time', y = 'count')
